# %% [markdown]
# Create a function called return_sum_of_two_numbers that accepts two parameters and returns the sum of two numbers.

# %%
# your code here

# uncomment 2 lines below to test
# print(return_sum_of_two_numbers(1, 2))
#print(type(return_sum_of_two_numbers(1, 2)))

# %% [markdown]
# Create a function called return_difference_of_two_numbers that accepts two parameters and returns the difference of two numbers.

# %%
# your code here


# uncomment 2 lines below to test
# print(return_difference_of_two_numbers(2, 1))
# print(type(return_difference_of_two_numbers(2, 1)))

# %% [markdown]
# Create a function called return_product_of_two_numbers that accepts two parameters and returns the product of two numbers.

# %%
# your code here

# print(return_product_of_two_numbers(2, 3))
# print(type(return_product_of_two_numbers(2, 3)))

# %% [markdown]
# Create a function called return_quotient_of_two_numbers that accepts two parameters and returns the quotient of two numbers.

# %%
# your code here

# print(return_quotient_of_two_numbers(8, 2))
# print(type(return_quotient_of_two_numbers(8, 2)))

# %% [markdown]
# Create a function called return_remainder_of_two_numbers that accepts two parameters and returns the remainder of two numbers.

# %%
# your code here

# print(return_remainder_of_two_numbers(7, 2))
# print(type(return_remainder_of_two_numbers(7, 2)))
